# %%
import requests
import pandas as pd
import pymongo

# %%
#mc = pymongo.MongoClient()

# %%
#db = mc['games']
#ig_data = db['ig_data']

# %%
with open('.secrets/igdb-api-key') as f:
    api_key = f.read().strip()

# %%
url = "https://api-v3.igdb.com/games"
headers = {'user-key': api_key}
params = {'limit': 50, 'fields': "*; where first_release_date > 1356998400 & first_release_date < 1388534400;"}

# %%
results = requests.get(url, headers=headers, params=params)

# %%
results.headers
# Out:
# {'Date': 'Fri, 26 Jul 2019 03:35:40 GMT', 'Content-Type': 'application/json;charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dc842c735f0dc203bfee75e112cd9ebd31564112140; expires=Sat, 25-Jul-20 03:35:40 GMT; path=/; domain=.igdb.com; HttpOnly', 'X-Count': '1929', 'Via': '1.1 vegur', 'Strict-Transport-Security': 'max-age=15552000; preload', 'X-Content-Type-Options': 'nosniff', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '4fc3532bca6b3b78-YVR', 'Content-Encoding': 'gzip'}

# %%
results.json()
# Out:
# [{'id': 22707,
#   'category': 0,
#   'cover': 16760,
#   'created_at': 1471392000,
#   'first_release_date': 1388448000,
#   'game_modes': [1],
#   'keywords': [2045],
#   'name': 'Sweet 33',
#   'platforms': [6, 14],
#   'player_perspectives': [3],
#   'popularity': 1.0,
#   'release_dates': [55261, 55262],
#   'screenshots': [30395],
#   'similar_games': [14702,
#    15830,
#    17009,
#    18462,
#    19255,
#    56146,
#    61634,
#    69409,
#    72277,
#    79672],
#   'slug': 'sweet-33',
#   'summary': 'You\'ll have to think fast and sweet-talk even faster to complete this epic love quest! You wake up all alone in the desert with only one thought in your mind: "I have to get married right this minute!" Luckily, a nearby building bearing the sign "Fangamer: Suite 33" is filled with potential significant others! Seek them out and woo them until you\'ve captured their hearts! Who knows, your walk down the aisle might just be FANtastic!',
#   'tags': [536872957],
# ...

# %%
data = results.json()

# %%
#ig_data.insert_many(data)

# %%
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (10, 40)

# %%
df.T
# Out:
#                                                                          0  \
# age_ratings                                                            NaN
# aggregated_rating                                                      NaN
# aggregated_rating_count                                                NaN
# bundles                                                                NaN
# category                                                                 0
# collection                                                             NaN
# cover                                                                16760
# created_at                                                      1471392000
# external_games                                                         NaN
# first_release_date                                              1388448000
# franchise                                                              NaN
# ...
